# %%
import requests
from IPython.core.display import HTML
styles = requests.get("https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/cs109.css").text
HTML(styles)
# Out:
# <style>
# blockquote { background: #AEDE94; }
# h1 {
#     padding-top: 25px;
#     padding-bottom: 25px;
#     text-align: left;
#     padding-left: 10px;
#     background-color: #DDDDDD;
#     color: black;
# }
# h2 {
#     padding-top: 10px;
#     padding-bottom: 10px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
#
# div.exercise {
# 	background-color: #ffcccc;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# }
# div.theme {
# 	background-color: #DDDDDD;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# 	font-size: 18pt;
# }
# div.gc {
# 	background-color: #AEDE94;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# 	font-size: 12pt;
# }
# p.q1 {
#     padding-top: 5px;
#     padding-bottom: 5px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
# header {
# ...

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
import requests
import json
import re
from requests import get
import collections
import pandas as pd

# %%
hs2010 = pd.read_csv('2010_Top_100_HS.csv')
hs2011 = pd.read_csv('2011_Top_100_HS.csv')
hs2012 = pd.read_csv('2012_Top_100_HS.csv')
hs2013 = pd.read_csv('2013_Top_100_HS.csv')
hs2014 = pd.read_csv('2014_Top_100_HS.csv')
hs2015 = pd.read_csv('2015_Top_100_HS.csv')
hs2016 = pd.read_csv('2016_Top_100_HS.csv')
hs2017 = pd.read_csv('2017_Top_100_HS.csv')

# %%
topHS = pd.concat([hs2010, hs2011, hs2012, hs2013, hs2014, hs2015, hs2016, hs2017], ignore_index=True)

# %%
bpi = pd.read_csv('ESPN_BPI.csv')
playerd = pd.read_csv('PlayerD.csv')
playerd
# Out:
#         Rk                                             Player Class   Season Pos                 School       Conf   G    MP  MP.1   FG   FGA   2P   2PA   3P  3PA   FT  FTA  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0        1                        Kemba Walker\kemba-walker-1    JR  2010-11   G            Connecticut   Big East  41  1543  37.6  7.7    18  5.9  12.5  1.8  5.5  6.3  7.7  1.3  4.1  5.4  4.5  1.9  0.2  2.3  1.4  23.5
# 1        2                   Devonte' Graham\devonte-graham-1   NaN  2017-18   G                 Kansas     Big 12  39  1474  37.8  5.1  12.8  2.3   5.8  2.8  6.9  4.3  5.2  0.6  3.4    4  7.2  1.6  0.1  2.8  1.4  17.3
# 2        3                          Tyus Battle\tyus-battle-1    SO  2017-18   G               Syracuse        ACC  37  1443    39  6.3  15.8  4.2   9.4  2.1  6.5  4.5  5.4  0.5  2.5  2.9  2.1  1.5  0.2  2.4    2  19.2
# ...

# %%
playerd.sort_values(by = ['Season'], ascending = False, inplace = True)
playerd
# Out:
#         Rk                                     Player  Class   Season  Pos                  School       Conf   G    MP  MP.1   FG   FGA   2P   2PA   3P  3PA   FT  FTA  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 201     Rk                                     Player  Class   Season  Pos                  School       Conf   G    MP    MP   FG   FGA   2P   2PA   3P  3PA   FT  FTA  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 100     Rk                                     Player  Class   Season  Pos                  School       Conf   G    MP    MP   FG   FGA   2P   2PA   3P  3PA   FT  FTA  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 2174  2173                    Ryan Allen\ryan-allen-3     FR  2017-18    G                Delaware        CAA  30  1072  35.7  5.4  13.4  2.6     6  2.9  7.4  1.6  2.2  0.3  2.2   2.5  1.5  0.5  0.2  1.6  2.9  15.3
# ...

# %%
playerdropped = playerd.drop_duplicates('Player')

# %%
playerdropped.shape
# Out:
# (1728, 27)

# %%
playerdrop = playerdropped[1:]

# %%
bpi
# Out:
#        Rk                    Team       Conf     W-L  BPI Off  BPI Def   BPI  Year
# 0       1                  Kansas     Big 12    37-3     12.4      9.6  21.9  2008
# 1       2          North Carolina        ACC    36-3     19.2      1.0  20.2  2008
# 2       3                 Memphis      C-USA    38-2     11.3      8.0  19.3  2008
# 3       4                    UCLA     Pac-12    35-4      7.9     10.9  18.9  2008
# 4       5                    Duke        ACC    28-6     13.8      4.3  18.2  2008
# 5       6              Georgetown   Big East    28-6      4.3     12.9  17.2  2008
# 6       7           West Virginia   Big East   26-11      8.9      7.7  16.6  2008
# 7       8               Wisconsin    Big Ten    31-5      2.1     14.4  16.5  2008
# 8       9               Tennessee        SEC    31-5     13.3      2.8  16.1  2008
# 9      10              Louisville   Big East    27-9      7.1      9.1  16.1  2008
# ...

# %%
playerdrop
# Out:
#         Rk                                 Player Class   Season Pos                  School       Conf   G    MP  MP.1   FG   FGA   2P   2PA   3P  3PA   FT  FTA  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 2174  2173                Ryan Allen\ryan-allen-3    FR  2017-18   G                Delaware        CAA  30  1072  35.7  5.4  13.4  2.6     6  2.9  7.4  1.6  2.2  0.3  2.2   2.5  1.5  0.5  0.2  1.6  2.9  15.3
# 1258  1257          Cameron Young\cameron-young-1    SR  2017-18   G              Quinnipiac       MAAC  33  1124  34.1  5.7  13.4  3.7     7  1.9  6.4  5.6  7.4  1.8    5   6.8  2.8  1.3  0.3  2.8  2.6  18.8
# 1004  1003          Andrew Rowsey\andrew-rowsey-1    SR  2017-18   G               Marquette   Big East  35  1143  32.7  5.9  14.1  2.4   5.5  3.6  8.6    5  5.5  0.4  2.6     3  4.8  0.9  0.2  2.8  2.4  20.5
# ...

# %%
player_d = pd.read_csv('player_d_final.csv', encoding = 'ISO-8859-1')
draft_results = pd.read_csv('draft_results_10-18.csv', encoding = 'ISO-8859-1')
bpi = pd.read_csv('ESPN_BPI.csv', encoding = 'ISO-8859-1')

# %%
player_d
# Out:
#       Unnamed: 0    Rk                                             Player Class   Season Pos                 School       Conf   G    MP  MP.1   FG   FGA   2P   2PA   3P  3PA   FT  FTA  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0            NaN  1257                      Cameron Young\cameron-young-1    SR  2017-18   G             Quinnipiac       MAAC  33  1124  34.1  5.7  13.4  3.7   7.0  1.9  6.4  5.6  7.4  1.8  5.0   6.8  2.8  1.3  0.3  2.8  2.6  18.8
# 1            NaN  1003                      Andrew Rowsey\andrew-rowsey-1    SR  2017-18   G              Marquette   Big East  35  1143  32.7  5.9  14.1  2.4   5.5  3.6  8.6  5.0  5.5  0.4  2.6   3.0  4.8  0.9  0.2  2.8  2.4  20.5
# 2            NaN  1709                        Thomas Welsh\thomas-welsh-1    SR  2017-18   C                   UCLA     Pac-12  33  1096  33.2  4.9  10.1  3.5   6.7  1.4  3.4  1.5  1.8  2.6  8.2  10.8  1.4  0.7  0.9  1.0  2.4  12.6
# ...

# %%
draft_results['key'] = draft_results['school'] + draft_results['year']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/new_p3_env/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1011         try:
# -> 1012             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1013         except TypeError:
#
# ~/new_p3_env/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# ~/new_p3_env/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# TypeError: must be str, not int
#
# ...
